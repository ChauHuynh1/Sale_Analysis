# %% [markdown]
# <h1 style="color:#ffc0cb;font-size:70px;font-family:Georgia;text-align:center;"><strong>Personal Project</strong></h1>
# <h2 style="color:#ffc0cb;font-size:70px;font-family:Georgia;text-align:center;"><strong>Sale analysis</strong></h2>
#
# ### <b>Author Name: Nguyen Dang Huynh Chau</b>
#
# ![5e0c28b42f821e329a00fd1d9d280649.gif](attachment:5e0c28b42f821e329a00fd1d9d280649.gif)

# %% [markdown]
# <h1 style="color:#ffc0cb;font-size:40px;font-family:Georgia;text-align:center;"><strong> 📜 Table of Content</strong></h1>
#
# ### 1. [Data Preparation](#1)
#
# 1.1 [Introduction](#1.1)
#
# 1.2 [Target question for insights](#1.2)
#
# 1.3 [Importing Necessary Libraries and datasets](#1.3)
#
# 1.4 [Data Retrieving](#1.4)
#
# 1.5 [Data information](#1.5)
#
# <br>
#
# ### 2. [Data Cleaning](#2)
#
# 2.1 [About This Dataset](#2.1)
#
# 2.2 [Data preprocessing](#2.2)
#
# > - 2.2.1 [Drop column `ID`](#2.2.1)
# > - 2.2.2 [Rename columns](#2.2.2)
# > - 2.2.3 [Drop Duplicate](#2.2.3)
# > - 2.2.4 [Check the content](#2.2.4)
# > - 2.2.5 [Drop NAN values](#2.2.5)
# > - 2.2.6 [Convert Data Type](#2.2.6)
#
# 2.3 [Upper Case the content](#2.3)
#
# 2.4 [Extra-whitespaces](#2.4)
#
# 2.5 [Descriptive statistics for Central Tendency](#2.5)
#
# <br>
#
# ### 3. [Data exploration (EDA)](#3)
#
# 3.1 [Overall look on target variable](#3.1)
#
# > - 3.1.1 [Distribution of Sepsis](#3.1.1)
# > - 3.1.2 [Proportion of Sepsis](#3.1.1)
#
# 3.2 [Frequency of each corresponiding Target variable type](#3.2)
#
# > - 3.2.1 [How old are they?](#3.2.1)
# > - 3.2.2 [How much they weight?](#3.2.2)
# > - 3.2.3 [How high PL (Blood Work Result-1 (mu U/ml)) that the Sepsis is likely to get?](#3.2.3)
# > - 3.2.4 [How high PR ((Blood Pressure (mm Hg)) that the Sepsis is likely to get?](#3.2.4)
# > - 3.2.5 [How high SK (Blood Work Result-2 (mm) that the Sepsis is likely to get?](#3.2.5)
# > - 3.2.6 [How high TS (Blood Work Result-3 (mu U/ml)) that the Sepsis is likely to get?](#3.2.6)
# > - 3.2.7 [How high BD2 (Blood Work Result-4 (mu U/ml)) that the Sepsis is likely to get?](#3.2.7)
# > - 3.2.8 [How high BD2 (Blood Work Result-4 (mu U/ml)) that the Sepsis is likely to get?](#3.2.8)
# > - 3.2.9 [Scatter matrix](#3.2.8)
#
# 3.3 [Statistical Test for Correlation](#3.3)
#
# 3.4 [Summary](#3.3)
#
# <br>

# %% [markdown]
# <a id="1"></a>
# <h1 style="color:#ffc0cb;font-size:40px;font-family:Georgia;text-align:center;"><strong> ✍️ 1. Data Preparation</strong></h1>

# %% [markdown]
# <a id="1.1"></a>
# # ️🎯 1.1 Introduction
# ****
#
# <p style="list-style-type:circle;font-family:Yu Mincho Demibold;font-size:20px;color:black"> Sale analysis is an extremely essential process in every enterprise. Since then, Preparing, cleaning the data for a better sale analysis is also vital. In this mini project, I want to perform the cleaning processing and the sale analysis part. </p>

# %% [markdown]
# <a id="1.2"></a>
# # ️🎯 1.2 Target question for insights
# ****
# <ul style="list-style-type:circle;font-family:Yu Mincho Demibold;font-size:20px;color:black">
#     <li>How <span style="color:#122ecc;">Price </span> has effected the sale target?</li>
#     <li>Which <span style="color:#122ecc;">date/time </span> has the highest sale?</li>
#     <li>Which <span style="color:#122ecc;">City in the US </span> has the highest sale?</li>
#     <li>Which <span style="color:#122ecc;">Product</span> has the highest sale?</li>
# </ul>

# %% [markdown]
# <a id="1.3"></a>
# # ✴️ 1.3 Importing Necessary Libraries and datasets
# ****

# %%
import sys
# !{sys.executable} -m pip -q install missingno

# import libraries which are pandas and numpy
import pandas as pd
import numpy as np
import missingno as msno
import os


#for plots
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]= 15,10

#Libraries for plotting
# Modules for data visualization
import seaborn as sns
import plotly.express as px
import matplotlib.patches as mpatches
sns.set_theme(style="ticks", color_codes=True) #set theme in seaborn
# scatter matrix library
from pandas.plotting import scatter_matrix

#This is is for Correlation test
from scipy.stats import spearmanr
#This is is for Mann-Whitney Testing
import scipy.stats as stats

# %% [markdown]
# ## Check numpy and pandas version

# %%
# check the version of the packages
print("Numpy version: ", np.__version__)
print("Pandas version: ",pd.__version__)
! python --version
# Out:
# Numpy version:  1.21.5
# Pandas version:  1.4.2
# Python 3.9.12

# %% [markdown]
# ### ------------> OBSERVATION
# ***
# I want to check the numpy and pandas version since I want to make sure the verson is appropriate for my work load. Currently, it is still appropriate

# %% [markdown]
# <a id="1.4"></a>
# # 📲 1.4 Data Retrieving
# ***

# %%
path = "./Sales_Data"
files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files

all_months_data = pd.DataFrame()

for file in files:
    current_data = pd.read_csv(path+"/"+file)
    all_months_data = pd.concat([all_months_data, current_data])
    
all_months_data.to_csv("all_data.csv", index=False)

# %% [markdown]
# #### Read in updated dataframe

# %%
sale_df = pd.read_csv("all_data.csv")
sale_df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# <a id="1.5"></a>
# # 🔈 1.5 Data Information
# ****
# I want to have an overall look on both of the train and test dataset, so I use .shape and .info() function in python to do that.

# %%
print ("The shape of the train data is (row, column):"+ str(sale_df.shape))
print (sale_df.info())
# Out:
# The shape of the train data is (row, column):(186850, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB
# None

# %% [markdown]
# ### ------------> OBSERVATION
# ***
# From this, the information that I gained from the train dataset are the total paitent record is 186850 with some missing data.

# %% [markdown]
# <a id="2"></a>
# <h1 style="color:#ffc0cb;font-size:40px;font-family:Georgia;text-align:center;"><strong> 🧹 2. Data Cleaning</strong></h1>

# %% [markdown]
# <a id="2.1"></a>
# # 🦄 2.1 About This Dataset
# ***
# **Categorical:**
#
# - **Norminal**(Nominal variable)
#    > - **Order ID** (Order ID)
#    > - **Product** (Product Name)
#    > - **Purchase Address** (The address to the purchaser location)
#
# ***
# **Numeric:**
# - **Discrete**
#   >  - **Quantity Ordered** (The quantity that the customer has bought)
#
# - **Continous**
# >  - **Price Each** (The price of each product)
# >  - **Order Date** (The Date that the customer bought the products)

# %% [markdown]
# <a id="2.2"></a>
# # ❌ 2.2 Data preprocessing
# ***

# %% [markdown]
# <a id="2.2.1"></a>
# ## 🔧 2.2.1 Drop column `ID`
# ***
# <ul style="list-style-type:circle;font-family:Yu Mincho Demibold;font-size:20px;color:black">
#     <li> In order to avoid data leakage, I desire to drop column <span style="color:#122ecc;">ID </span></li>
# </ul>

# %%
sale_df = sale_df.drop(columns=['Order ID'])

# %% [markdown]
# <a id="2.2.2"></a>
# ## ⛏ 2.2.2 Rename columns
# ***
# Some of the column was not well-writen in a consistent constraint so I want to rename them.

# %%
sale_df.rename(columns={"Quantity Ordered": "Quantity", "Price Each": "Price",
                        "Order Date": "Order_Date", "Purchase Address": "Purchase_Address"
                       }, inplace=True)

# %% [markdown]
# <a id="2.2.3"></a>
# ## ⌛ 2.2.3 Drop duplicate
# ***
# Although, there may be no duplicated value but I still want to drop duplicate.

# %%
print ("The shape of the data set before dropping duplicated:"+ str(sale_df.shape))

sale_df = sale_df.drop_duplicates()

print ("The shape of the data set after dropping duplicated:"+ str(sale_df.shape))
# Out:
# The shape of the data set before dropping duplicated:(186850, 5)
# The shape of the data set after dropping duplicated:(185688, 5)

# %% [markdown]
# <a id="2.2.4"></a>
# ## 🦄 2.2.4 Check the content:
# ***

# %%
sale_df['Product'].value_counts()
# Out:
# USB-C Charging Cable          21859
# Lightning Charging Cable      21610
# AAA Batteries (4-pack)        20612
# AA Batteries (4-pack)         20558
# Wired Headphones              18849
# Apple Airpods Headphones      15525
# Bose SoundSport Headphones    13298
# 27in FHD Monitor               7498
# iPhone                         6840
# 27in 4K Gaming Monitor         6225
# 34in Ultrawide Monitor         6174
# Google Phone                   5522
# Flatscreen TV                  4794
# Macbook Pro Laptop             4721
# ThinkPad Laptop                4126
# 20in Monitor                   4098
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# Product                           1
# Name: Product, dtype: int64

# %%
sale_df['Quantity'].value_counts()
# Out:
# 1                   168291
# 2                    13321
# 3                     2920
# 4                      806
# 5                      236
# 6                       80
# 7                       24
# 8                        5
# 9                        3
# Quantity Ordered         1
# Name: Quantity, dtype: int64

# %%
sale_df['Price'].value_counts()
# Out:
# 11.95         21859
# 14.95         21610
# 2.99          20612
# 3.84          20558
# 11.99         18849
# 150           15426
# 99.99         13298
# 149.99         7498
# 700            6802
# 389.99         6225
# 379.99         6174
# 600            5487
# 300            4774
# 1700           4699
# 999.99         4126
# 109.99         4098
# 400            2056
# 600.0          1347
# 150.0            99
# 700.0            38
# 1700.0           22
# 300.0            20
# 400.0             9
# Price Each        1
# Name: Price, dtype: int64

# %%
sale_df['Price'].value_counts()
# Out:
# 11.95         21859
# 14.95         21610
# 2.99          20612
# 3.84          20558
# 11.99         18849
# 150           15426
# 99.99         13298
# 149.99         7498
# 700            6802
# 389.99         6225
# 379.99         6174
# 600            5487
# 300            4774
# 1700           4699
# 999.99         4126
# 109.99         4098
# 400            2056
# 600.0          1347
# 150.0            99
# 700.0            38
# 1700.0           22
# 300.0            20
# 400.0             9
# Price Each        1
# Name: Price, dtype: int64

# %%
sale_df['Purchase_Address'].value_counts()
# Out:
# 193 Forest St, San Francisco, CA 94016    9
# 223 Elm St, Los Angeles, CA 90001         8
# 279 Sunset St, San Francisco, CA 94016    8
# 176 North St, San Francisco, CA 94016     7
# 550 Cherry St, San Francisco, CA 94016    7
#                                          ..
# 377 Forest St, San Francisco, CA 94016    1
# 440 8th St, Boston, MA 02215              1
# 727 14th St, Atlanta, GA 30301            1
# 732 Lake St, Seattle, WA 98101            1
# 209 11th St, Atlanta, GA 30301            1
# Name: Purchase_Address, Length: 140788, dtype: int64

# %%
sale_df['Order_Date'].value_counts()
# Out:
# 12/15/19 20:16    8
# 12/11/19 13:24    7
# 04/02/19 13:24    7
# 10/30/19 21:28    7
# 05/12/19 16:00    6
#                  ..
# 08/21/19 10:23    1
# 08/04/19 13:02    1
# 08/02/19 19:09    1
# 08/30/19 23:15    1
# 06/25/19 14:33    1
# Name: Order_Date, Length: 142396, dtype: int64

# %% [markdown]
# ### ------------> OBSERVATION
# ***
# From this report, I saw there are some unnecessary column names are considered the values of the column so I will drop them all

# %%
sale_df = sale_df[~sale_df['Product'].isin(['Product'])]
sale_df = sale_df[~sale_df['Quantity'].isin(['Quantity Ordered'])]
sale_df = sale_df[~sale_df['Price'].isin(['Price Each'])]
sale_df = sale_df[~sale_df['Purchase_Address'].isin(['Purchase Address'])]
sale_df = sale_df[~sale_df['Order_Date'].isin(['Order Date'])]

# %% [markdown]
# <a id="2.2.5"></a>
# ## 👀 2.2.5 Dealing with missing values
# ***
#
# <p style="list-style-type:circle;font-family:Yu Mincho Demibold;font-size:20px;color:black"> I want to drop those columns having the missing values that is higher than 50 percent, since If I impute them, there will be bias in my data
# </p>

# %%
def missing_percentage(df):
    """This function takes a DataFrame(df) as input and returns two columns, total missing values and total missing values percentage"""
    total = df.isnull().sum().sort_values(ascending=False)[df.isnull().sum().sort_values(ascending=False) != 0]
    percent = round(df.isnull().sum().sort_values(ascending=False) / len(df) * 100, 2)[
        round(df.isnull().sum().sort_values(ascending=False) / len(df) * 100, 2) != 0]
    return pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

# display missing values in descending
print("Missing values in the dataframe in descending: \n", missing_percentage(sale_df).sort_values(by='Total', ascending=False))

# visualize where the missing values are located
msno.matrix(sale_df, color=(255 / 255, 192 / 255, 203 / 255))
pink_patch = mpatches.Patch(color='pink', label='present value')
white_patch = mpatches.Patch(color='white', label='absent value')
plt.legend(handles=[pink_patch, white_patch])
plt.show()
# Out:
# Missing values in the dataframe in descending:
#                    Total  Percent
# Product               1      NaN
# Quantity              1      NaN
# Price                 1      NaN
# Order_Date            1      NaN
# Purchase_Address      1      NaN

# %% [markdown]
# ### ------------> OBSERVATION
# ***
# The missing value is not considerable so I want to drop all of them

# %%
sale_df = sale_df.dropna(how='all')
sale_df.head()
# Out:
#                 Product Quantity   Price      Order_Date  \
# 0    Macbook Pro Laptop        1    1700  12/30/19 00:01
# 1    LG Washing Machine        1   600.0  12/29/19 07:03
# 2  USB-C Charging Cable        1   11.95  12/12/19 18:21
# 3      27in FHD Monitor        1  149.99  12/22/19 15:13
# 4  USB-C Charging Cable        1   11.95  12/18/19 12:38
#
#                          Purchase_Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# <a id="2.2.6"></a>
# ## 🦄 2.2.6 Convert Data Type:
# ***

# %%
sale_df['Product'] = sale_df['Product'].astype('string')
sale_df['Quantity'] = sale_df['Quantity'].astype('int')
sale_df['Price'] = sale_df['Price'].astype('float')
sale_df['Purchase_Address'] = sale_df['Purchase_Address'].astype('string')
sale_df['Order_Date']= pd.to_datetime(sale_df['Order_Date'])

# %% [markdown]
# <a id="2.2.6"></a>
# ## 🦄 2.2.6 Add columns:
# ***

# %% [markdown]
# ## Add Month:

# %%
sale_df['Month'] = pd.to_datetime(sale_df['Order_Date']).dt.month
sale_df.head()
# Out:
#                 Product  Quantity    Price          Order_Date  \
# 0    Macbook Pro Laptop         1  1700.00 2019-12-30 00:01:00
# 1    LG Washing Machine         1   600.00 2019-12-29 07:03:00
# 2  USB-C Charging Cable         1    11.95 2019-12-12 18:21:00
# 3      27in FHD Monitor         1   149.99 2019-12-22 15:13:00
# 4  USB-C Charging Cable         1    11.95 2019-12-18 12:38:00
#
#                          Purchase_Address  Month
# 0  136 Church St, New York City, NY 10001     12
# 1     562 2nd St, New York City, NY 10001     12
# 2    277 Main St, New York City, NY 10001     12
# 3     410 6th St, San Francisco, CA 94016     12
# 4           43 Hill St, Atlanta, GA 30301     12

# %% [markdown]
# ## Add Year:

# %%
sale_df['Year'] = pd.to_datetime(sale_df['Order_Date']).dt.year
sale_df.head()
# Out:
#                 Product  Quantity    Price          Order_Date  \
# 0    Macbook Pro Laptop         1  1700.00 2019-12-30 00:01:00
# 1    LG Washing Machine         1   600.00 2019-12-29 07:03:00
# 2  USB-C Charging Cable         1    11.95 2019-12-12 18:21:00
# 3      27in FHD Monitor         1   149.99 2019-12-22 15:13:00
# 4  USB-C Charging Cable         1    11.95 2019-12-18 12:38:00
#
#                          Purchase_Address  Month  Year
# 0  136 Church St, New York City, NY 10001     12  2019
# 1     562 2nd St, New York City, NY 10001     12  2019
# 2    277 Main St, New York City, NY 10001     12  2019
# 3     410 6th St, San Francisco, CA 94016     12  2019
# 4           43 Hill St, Atlanta, GA 30301     12  2019

# %% [markdown]
# ## Add City:

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

sale_df['City'] = sale_df['Purchase_Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
sale_df.head()
# Out:
#                 Product  Quantity    Price          Order_Date  \
# 0    Macbook Pro Laptop         1  1700.00 2019-12-30 00:01:00
# 1    LG Washing Machine         1   600.00 2019-12-29 07:03:00
# 2  USB-C Charging Cable         1    11.95 2019-12-12 18:21:00
# 3      27in FHD Monitor         1   149.99 2019-12-22 15:13:00
# 4  USB-C Charging Cable         1    11.95 2019-12-18 12:38:00
#
#                          Purchase_Address  Month  Year                 City
# 0  136 Church St, New York City, NY 10001     12  2019  New York City  (NY)
# 1     562 2nd St, New York City, NY 10001     12  2019  New York City  (NY)
# 2    277 Main St, New York City, NY 10001     12  2019  New York City  (NY)
# 3     410 6th St, San Francisco, CA 94016     12  2019  San Francisco  (CA)
# 4           43 Hill St, Atlanta, GA 30301     12  2019        Atlanta  (GA)

# %% [markdown]
# <a id="2.3"></a>
# # 💭 2.3 Upper Case the content
# ****

# %%
# Cast all values inside the dataframe (except the columns' name) into upper case.
sale_df = sale_df.applymap(lambda s: s.upper() if type(s) == str else s)
sale_df.head(3)
# Out:
#                 Product  Quantity    Price          Order_Date  \
# 0    MACBOOK PRO LAPTOP         1  1700.00 2019-12-30 00:01:00
# 1    LG WASHING MACHINE         1   600.00 2019-12-29 07:03:00
# 2  USB-C CHARGING CABLE         1    11.95 2019-12-12 18:21:00
#
#                          Purchase_Address  Month  Year                 City
# 0  136 CHURCH ST, NEW YORK CITY, NY 10001     12  2019  NEW YORK CITY  (NY)
# 1     562 2ND ST, NEW YORK CITY, NY 10001     12  2019  NEW YORK CITY  (NY)
# 2    277 MAIN ST, NEW YORK CITY, NY 10001     12  2019  NEW YORK CITY  (NY)

# %% [markdown]
# <a id="2.4"></a>
# # 📚 2.4 Extra-whitespaces:
# ***

# %%
def whitespace_remover(df):
    """
    The function will remove extra leading and trailing whitespace from the data.
    """
    # iterating over the columns
    for i in df.columns:
        # checking datatype of each columns
        if df[i].dtype == 'object' or df[i].dtype == 'str':
            # applying strip function on column
            df[i] = df[i].map(str.strip)
        else:
            # if condition is False then it will do nothing.
            pass

# remove all the extra whitespace
whitespace_remover(sale_df)

# %% [markdown]
# <a id="2.5"></a>
# # 📊 2.5 Descriptive statistics for Central Tendency
# ****
# I want to check and validate of the numerical columns:
#
# 1. Check overview statistics:
# 2. Check the scale
# 3. Check outliers

# %%
# see the static of all numerical column
sale_df.describe().T
# Out:
#              count         mean         std      min      25%      50%  \
# Quantity  185686.0     1.124544    0.443069     1.00     1.00     1.00
# Price     185686.0   184.519255  332.843838     2.99    11.95    14.95
# Month     185686.0     7.058653    3.502932     1.00     4.00     7.00
# Year      185686.0  2019.000183    0.013530  2019.00  2019.00  2019.00
#
#              75%     max
# Quantity     1.0     9.0
# Price      150.0  1700.0
# Month       10.0    12.0
# Year      2019.0  2020.0

# %%
plt.rcParams['figure.figsize'] = [20, 15]
# plot the boxplot to see the outlier of each numerical column
sns.boxplot(data=sale_df,orient="v")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ---------> OBSERVATION
# ****
# The scale of this dataset is acceptable so I do not need to consider the outliers

# %% [markdown]
# <a id="3"></a>
# <h1 style="color:#ffc0cb;font-size:40px;font-family:Georgia;text-align:center;"><strong> 📊 3. Data exploration (EDA)</strong></h1>
